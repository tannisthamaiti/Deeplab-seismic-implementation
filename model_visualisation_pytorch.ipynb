# %%
# %cd /content/drive/My Drive/PETAI-master
# Out:
# /content/drive/My Drive/PETAI-master

# %%
from core.data_loader import *
import torch

# %%
# !pip install torchviz
# Out:
# ...
#      |████████████████████████████████| 51kB 3.1MB/s
# ...
#   Created wheel for torchviz: filename=torchviz-0.0.1-cp36-none-any.whl size=3523 sha256=cc198f228269e05193e0ab64779ec7ad0ef6b0ca768f203775a11f9f088463e1
#   Stored in directory: /root/.cache/pip/wheels/2a/c2/c5/b8b4d0f7992c735f6db5bfa3c5f354cf36502037ca2b585667
# Successfully built torchviz
# ...

# %%
from torchviz import make_dot

# %%
val_set = PatchLoader(is_transform=True,
                        split='val',
                        stride=50,
                        patch_size=99)

# %%
n_classes = 6

valloader = data.DataLoader(val_set,
                            batch_size=16,
                            num_workers=1)

# %%
model = torch.load("Jan18_233504_SeismicNet/seismic_model.pkl")

# %%
model
# Out:
# DataParallel(
#   (module): SeismicNet(
#     (start): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#     )
#     (encode1): ResidualBlock(
#       (block): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): PReLU(num_parameters=1)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (encode2): ResidualBlock(
#       (block): Sequential(
# ...

# %%
for i, (images, labels) in enumerate(valloader):
    image_original, labels_original = images, labels
    img = image_original
    break

# %%
make_dot(model(img))

# %%
make_dot(model(img)).render("U-Net", format="jpg")
# Out:
# 'U-Net.jpg'
