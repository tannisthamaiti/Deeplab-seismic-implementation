# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Install tf Slim (which is included in the "tensorflow/models/research/" checkout)

# %%
# %cd /content/gdrive/My\ Drive/Tannistha\ Maiti/Deeplab-v3/slim
# Out:
# /content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/slim

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing slim.egg-info/PKG-INFO
# writing dependency_links to slim.egg-info/dependency_links.txt
# writing top-level names to slim.egg-info/top_level.txt
# reading manifest file 'slim.egg-info/SOURCES.txt'
# writing manifest file 'slim.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/deployment
# copying build/lib/deployment/model_deploy.py -> build/bdist.linux-x86_64/egg/deployment
# copying build/lib/deployment/model_deploy_test.py -> build/bdist.linux-x86_64/egg/deployment
# copying build/lib/deployment/__init__.py -> build/bdist.linux-x86_64/egg/deployment
# creating build/bdist.linux-x86_64/egg/datasets
# copying build/lib/datasets/dataset_factory.py -> build/bdist.linux-x86_64/egg/datasets
# ...

# %% [markdown]
# Folder for deeplab codes in my drive

# %%
# %cd /content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab
# Out:
# /content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab

# %%
# %ls
# Out:
# checkpoint/                 LICENSE
# common.py                   local_test_mobilenetv2.sh
# common_test.py              local_test.sh
# core/                       model/
# create_pascal_tf_record.py  model.py
# datasets/                   model_test.py
# deeplab_demo.ipynb          preprocessing.py
# deeplab_model.py            __pycache__/
# deprecated/                 README.md
# doc/                        resizer.py
# eval.py                     resnet_v2_101/
# evaluate.py                 SemanticSegmentation-Examples-master/
# evaluation/                 sizeChecker.py
# export_inference_graph.py   testing/
# export_model.py             training/
# g3doc/                      train.py
# images/                     train_tf.py
# inference_graph/            translate/
# inference.py                utils/
# __init__.py                 vis.py
# input_preprocess.py         Webcam_Segmentation.ipynb

# %% [markdown]
# Train the model to 300 steps.

# %%
# !python train.py --logtostderr --train_split="train" --model_variant="xception_65" \
  --atrous_rates=6 \
  --atrous_rates=12 \
  --atrous_rates=18 \
  --output_stride=16 \
  --decoder_output_stride=4 \
  --train_crop_size=513,513 \
  --train_batch_size=2 \
  --training_number_of_steps=300 \
  --fine_tune_batch_norm=true \
  --train_logdir="/content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/datasets/model_checkpoints/train" \
  --dataset="seismic" \
  --dataset_dir="/content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/datasets/tfrecord" \
  --tf_initial_checkpoint="/content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/datasets/pascal_vog_seg/init_models/deeplabv3_pascal_train_aug/model.ckpt"
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/slim-0.1-py3.6.egg/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %% [markdown]
# Evaluate the model on eval dataset

# %%
# !python eval.py \
--logtostderr \
--eval_split="val" \
--model_variant="xception_65" \
--atrous_rates=6 \
--atrous_rates=12 \
--atrous_rates=18 \
--output_stride=16 \
--decoder_output_stride=4 \
--eval_crop_size=513,513 \
--checkpoint_dir="/content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/datasets/model_checkpoints/train" \
--eval_logdir="/content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/datasets/model_checkpoints/eval" \
--dataset_dir="/content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/datasets/tfrecord" \
--dataset="seismic" \
--max_number_of_evaluations=2
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/slim-0.1-py3.6.egg/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From eval.py:243: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From eval.py:92: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0217 03:38:09.643005 140577251727232 module_wrapper.py:139] From eval.py:92: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From eval.py:92: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %% [markdown]
# Evaluate on test set (not working need to fix this!)

# %%
# !python vis.py \
--logtostderr \
--vis_split="test" \
--model_variant="xception_65" \
--atrous_rates=6 \
--atrous_rates=12 \
--atrous_rates=18 \
--output_stride=16 \
--decoder_output_stride=4 \
--eval_crop_size=513,513 \
--checkpoint_dir="/content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/datasets/model_checkpoints/train" \
--vis_logdir="/content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/datasets/CustomDataset/vis" \
--dataset_dir="/content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/datasets/tfrecord_test" \
--dataset="seismic" \
--max_number_of_iterations=1
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Tannistha Maiti/Deeplab-v3/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/slim-0.1-py3.6.egg/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From vis.py:327: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From vis.py:195: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0217 16:23:06.183350 140700964931456 module_wrapper.py:139] From vis.py:195: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From vis.py:195: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...
