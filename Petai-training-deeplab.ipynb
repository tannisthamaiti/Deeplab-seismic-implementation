# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from tensorflow import summary

# %%
# !pip install tensorboardcolab
from tensorboardcolab import TensorBoardColab
tb = TensorBoardColab()
# Out:
# ...
# Using TensorFlow backend.
# Wait for 8 seconds...
# TensorBoard link:
# http://fd113b19.ngrok.io

# %%
# %cd /content/gdrive/My\ Drive
# Out:
# /content/gdrive/My Drive

# %%
# %ls
# Out:
# '2019 AGES Student Declaration Form.pdf'  'Mathworks Matlab R2018b [x64] [PC]'/
#  abcdxyz.ipynb                             patch_images.ipynb
# 'Anyfile Notepad Files'/                   PETAI-master/
# 'ball bearing.TIF'                         Petai-training-deeplab.ipynb
# 'Colab Notebooks'/                        'Research Statement.pdf'
# 'CV of Enaiyat Ghani Ovy.pdf'              stl_files.zip
#  deeplab/                                 'Tannistha Maiti'/
# 'Getting started.pdf'                     'Unofficial Transcript.pdf'
# 'Invisalign Child Patient'/

# %%
# %cd PETAI-master/
# Out:
# /content/gdrive/My Drive/PETAI-master

# %%
# %ls
# Out:
# core/      runs/            train_deeplab_1channel_Resnet101.py
# data/      test/            train_deeplab_1channel_Resnet18.py
# dict.csv   test_deeplab.py  train_deeplab_1D.py
# LICENSE    test.py          train_deeplab.py
# README.md  testX/           train.py
# run/       trainData/       val/

# %%
pip install tensorboardX

# %%
# !python train.py --batch_size 32 --aug True --n_epoch 30
# Out:
# 401 701 255
# 99
# tcmalloc: large alloc 1951531008 bytes == 0x2b57c000 @  0x7f91d63191e7 0x7f91d3b36f71 0x7f91d3b9a55d 0x7f91d3b9abe7 0x7f91d3c32898 0x50ac25 0x50d390 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x58958c 0x5a067e 0x7f91d3b8606d 0x50a8af 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3
# tcmalloc: large alloc 1951531008 bytes == 0xc1e56000 @  0x7f91d63191e7 0x7f91d3b36f71 0x7f91d3b9a55d 0x7f91d3b9abe7 0x7f91d3c32898 0x50ac25 0x50d390 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x58958c 0x5a067e 0x7f91d3b8606d 0x50a8af 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3
# train.py:195: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# Epoch [1/30] training Loss: 10.0690
# ...

# %%
# !ls
# Out:
# core		 test.py
# data		 testX
# LICENSE		 trainData
# README.md	 train_deeplab_1channel_Resnet101.py
# run		 train_deeplab_1channel_Resnet18.py
# runs		 train_deeplab_1D.py
# test		 train_deeplab.py
# test_deeplab.py  train.py

# %%
# !python train_deeplab_1channel_Resnet18.py --train --batch_size 32 --aug True --n_epoch 30  --base_lr 0.07 --exp gn_ws_lr7e-3
# Out:
# tcmalloc: large alloc 1951531008 bytes == 0x2b388000 @  0x7f1f78d4c1e7 0x7f1f76569f71 0x7f1f765cd55d 0x7f1f765cdbe7 0x7f1f76665898 0x50ac25 0x50d390 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x58958c 0x5a067e 0x7f1f765b906d 0x50a8af 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3
# tcmalloc: large alloc 1951531008 bytes == 0xc1c62000 @  0x7f1f78d4c1e7 0x7f1f76569f71 0x7f1f765cd55d 0x7f1f765cdbe7 0x7f1f76665898 0x50ac25 0x50d390 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x58958c 0x5a067e 0x7f1f765b906d 0x50a8af 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=50 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "train_deeplab_1channel_Resnet18.py", line 495, in <module>
#     train(args)
# ...

# %%
# !python train_deeplab_1D.py --train --batch_size 32 --aug True --n_epoch 30  --base_lr 0.007 --exp bn_lr7e-3 --beta
# Out:
# tcmalloc: large alloc 1951531008 bytes == 0x2c466000 @  0x7f8e27d8b1e7 0x7f8e255a8f71 0x7f8e2560c55d 0x7f8e2560cbe7 0x7f8e256a4898 0x50ac25 0x50d390 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x58958c 0x5a067e 0x7f8e255f806d 0x50a8af 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3
# Traceback (most recent call last):
#   File "train_deeplab_1D.py", line 480, in <module>
#     train(args)
#   File "train_deeplab_1D.py", line 119, in train
#     patch_size=args.patch_size)
#   File "/content/gdrive/My Drive/PETAI-master/core/data_loader.py", line 28, in __init__
#     self.seismic = self.pad_volume(np.load(pjoin('data', 'train', 'train_seismic.npy')))
#   File "/usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py", line 453, in load
#     pickle_kwargs=pickle_kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/numpy/lib/format.py", line 738, in read_array
# ...

# %%
# !python test_deeplab.py --test --exp bn_lr7e-3 --split test1 --model_path 'data/deeplab_epoch9.pth'
# Out:
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=50 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "test_deeplab.py", line 258, in <module>
#     test(args)
#   File "test_deeplab.py", line 81, in test
#     torch.cuda.set_device(args.gpu)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 292, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 197, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:50

# %%
# !python test.py --model_path 'runs/Jan18_233504_SeismicNet/seismic_model.pkl'
# Out:
# split: test1, section: 0
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# split: test1, section: 1
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# split: test1, section: 2
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# split: test1, section: 3
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# split: test1, section: 4
